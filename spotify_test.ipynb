# %%
import requests
import boto3
import os
from dotenv import load_dotenv
import base64
import json
import datetime
import jwt
import pandas as pd
import pyarrow as pa
import logging

# %%
load_dotenv()
# Out:
# True

# %%
header = {
    "alg": "ES256",
    "kid": "LWRTH98832"

}

# %%
with open('AuthKey_LWRTH98832.p8', 'rb') as f:
    private_key = f.read()

# %%
claims = {
    "iss": "VW8B75VC55",  # Issuer of the token
    "exp": datetime.datetime.now(datetime.timezone.utc) + datetime.timedelta(hours=24), # Expiration time
    "iat": datetime.datetime.now(datetime.timezone.utc), # Issued at time

}

# %%
encoded_jwt = jwt.encode(claims, private_key, algorithm='ES256', headers=header)

# %%
encoded_jwt
# Out:
# 'eyJhbGciOiJFUzI1NiIsImtpZCI6IkxXUlRIOTg4MzIiLCJ0eXAiOiJKV1QifQ.eyJpc3MiOiJWVzhCNzVWQzU1IiwiZXhwIjoxNzQ0NjkxMDYxLCJpYXQiOjE3NDQ2MDQ2NjF9.te_4GIeKFxCwcupcsuC0pJLzucpOM-32wllUvrG6xC7aD9-3joLbHOrH3B4ihE6_r0ejPPRSDtmFb5g-gHBK7A'

# %%
response = requests.get('https://api.music.apple.com/v1/test',
                             headers = {"Authorization": f"Bearer  {encoded_jwt}"})

# %%
response
# Out:
# <Response [200]>

# %%
response
# Out:
# <Response [200]>

# %%
storefront = 'us'
genre_id = '1765343179'

# %%
response = requests.get('https://api.music.apple.com/v1/catalog/us/genres/14',
                             headers = {"Authorization": f"Bearer  {encoded_jwt}"})

# %%
response.json()
# Out:
# {'data': [{'id': '14',
#    'type': 'genres',
#    'href': '/v1/catalog/us/genres/14',
#    'attributes': {'parentName': 'Music', 'name': 'Pop', 'parentId': '34'}}]}

# %%
type = 'albums'

# %%
chart_response = requests.get(f'https://api.music.apple.com/v1/catalog/{storefront}/charts?types={type}&chart=most-played',
                              headers = {"Authorization": f"Bearer  {encoded_jwt}"})

# %%
chart_response.json()
# Out:
# {'results': {'albums': [{'chart': 'most-played',
#     'data': [{'id': '1796127242',
#       'type': 'albums',
#       'href': '/v1/catalog/us/albums/1796127242',
#       'attributes': {'copyright': '℗ 2025 OVO Sound under exclusive license to Santa Anna Label Group and OVO under exclusive license to Republic Records, a division of UMG Recordings',
#        'genreNames': ['R&B/Soul', 'Music'],
#        'releaseDate': '2025-02-14',
#        'upc': '808391285880',
#        'isMasteredForItunes': False,
#        'artwork': {'width': 3000,
#         'height': 3000,
#         'url': 'https://is1-ssl.mzstatic.com/image/thumb/Music211/v4/34/10/1e/34101e1f-f4b9-907a-ce47-3fba5b3ee5e8/50222.jpg/{w}x{h}bb.jpg',
#         'bgColor': '13181b',
#         'textColor1': 'faf9f3',
#         'textColor2': 'dbf5f9',
#         'textColor3': 'cbccc8',
#         'textColor4': 'b3c8cc'},
#        'url': 'https://music.apple.com/us/album/%24ome-%24exy-%24ongs-4-u/1796127242',
# ...

# %%
chart_response.json()['results']['albums'][0]
# Out:
# {'chart': 'most-played',
#  'data': [{'id': '1796127242',
#    'type': 'albums',
#    'href': '/v1/catalog/us/albums/1796127242',
#    'attributes': {'copyright': '℗ 2025 OVO Sound under exclusive license to Santa Anna Label Group and OVO under exclusive license to Republic Records, a division of UMG Recordings',
#     'genreNames': ['R&B/Soul', 'Music'],
#     'releaseDate': '2025-02-14',
#     'upc': '808391285880',
#     'isMasteredForItunes': False,
#     'artwork': {'width': 3000,
#      'height': 3000,
#      'url': 'https://is1-ssl.mzstatic.com/image/thumb/Music211/v4/34/10/1e/34101e1f-f4b9-907a-ce47-3fba5b3ee5e8/50222.jpg/{w}x{h}bb.jpg',
#      'bgColor': '13181b',
#      'textColor1': 'faf9f3',
#      'textColor2': 'dbf5f9',
#      'textColor3': 'cbccc8',
#      'textColor4': 'b3c8cc'},
#     'url': 'https://music.apple.com/us/album/%24ome-%24exy-%24ongs-4-u/1796127242',
#     'playParams': {'id': '1796127242', 'kind': 'album'},
#     'recordLabel': 'OVO Sound',
# ...

# %%
for i in chart_response.json()['results']['albums'][0]:
    print(i)
# Out:
# chart
# data
# href
# name
# next
# orderId

# %%
chart_response.json()['results']['albums'][0]['data'][1]
# Out:
# {'id': '1771970310',
#  'type': 'albums',
#  'href': '/v1/catalog/us/albums/1771970310',
#  'attributes': {'copyright': '℗ 2025 Alamo Records, LLC/Sony Music Entertainment',
#   'genreNames': ['Rap', 'Music', 'Hip-Hop/Rap'],
#   'releaseDate': '2025-03-28',
#   'upc': '196872525182',
#   'isMasteredForItunes': False,
#   'artwork': {'width': 3000,
#    'height': 3000,
#    'url': 'https://is1-ssl.mzstatic.com/image/thumb/Music211/v4/fa/d8/05/fad8054e-8980-eb74-22d5-b163a8e41d7e/196872525182.jpg/{w}x{h}bb.jpg',
#    'bgColor': '0a1e24',
#    'textColor1': 'e2e8ec',
#    'textColor2': 'b0c4ba',
#    'textColor3': 'b7bfc4',
#    'textColor4': '8fa39c'},
#   'url': 'https://music.apple.com/us/album/deep-thoughts/1771970310',
#   'playParams': {'id': '1771970310', 'kind': 'album'},
#   'recordLabel': 'Alamo',
#   'isCompilation': False,
#   'trackCount': 20,
#   'isSingle': False,
#   'name': 'Deep Thoughts',
#   'contentRating': 'explicit',
#   'artistName': 'Lil Durk',
# ...

# %%
len(chart_response.json()['results']['albums'][0]['data'])
# Out:
# 20

# %%
album_list = []

# %%
for i in range(len(chart_response.json()['results']['albums'][0]['data'])):
    album_name = chart_response.json()['results']['albums'][0]['data'][i]['attributes']['name']
    album_artist = chart_response.json()['results']['albums'][0]['data'][i]['attributes']['artistName']
    release_date = chart_response.json()['results']['albums'][0]['data'][i]['attributes']['releaseDate']
    key = i
    album_list.append([key, album_name, album_artist, release_date])

# %%
df = pd.DataFrame(album_list, columns=['key', 'album_name', 'album_artist', 'release_date'])

# %%
df['ingest_ts'] = datetime.datetime.now()

# %%
df.to_parquet('apple_music.parquet', engine='pyarrow')

# %%
s3 = boto3.client('s3')

# %%
bucket_name = 'your-bucket-name'
s3.upload_file('apple_music.parquet', 'apple_music/apple_music.parquet')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[99], line 2
#       1 bucket_name = 'your-bucket-name'
# ----> 2 s3.upload_file('apple_music.parquet', 'apple_music/apple_music.parquet')
#
# File /usr/local/lib/python3.13/site-packages/botocore/context.py:124, in with_current_context.<locals>.decorator.<locals>.wrapper(*args, **kwargs)
#     122 if hook:
#     123     hook()
# --> 124 return func(*args, **kwargs)
#
# TypeError: upload_file() missing 1 required positional argument: 'Key'

# %%
def upload_file(file_name, bucket, object_name=None):
    """Upload a file to an S3 bucket

    :param file_name: File to upload
    :param bucket: Bucket to upload to
    :param object_name: S3 object name. If not specified then file_name is used
    :return: True if file was uploaded, else False
    """

    # If S3 object_name was not specified, use file_name
    if object_name is None:
        object_name = os.path.basename(file_name)

    # Upload the file
    s3_client = boto3.client('s3')
    try:
        response = s3_client.upload_file(file_name, bucket, object_name)
    except:
        logging.error(f"Failed to upload {file_name} to {bucket}/{object_name}")
        return False
    return True
